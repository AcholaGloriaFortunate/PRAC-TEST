# %%
pip install empiricaldist
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: empiricaldist in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (0.7.2)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Run this code to install empiricaldist module for use on this Question 5
try:
    import empiricaldist
except ImportError:
    # !pip install empiricaldist

# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\DELL\Desktop\FORT RAVEN C 3\Year One\Semester one\Introduction to Data Science and Machine learning\Data\dataset.xlsx")

# %%
print(df)
# Out:
#     S/N             student_names  age weight   height  admission cohort 3
# 0     1            Adokorac Nancy   20     74    177.8                   1
# 1     2   Amutuhaire Faith Ahabwe   27     47   157.48                   1
# 2     3     KWAGALA JOANNA VICTOR   21     54   185.42                   1
# 3     4              mahoro cathy   23     30   185.42                   1
# 4     5  Mbabazi Hawa Bint Edrisa   19     59   175.26                   1
# 5     6       Nakanjako josephine   24     65   175.26                   1
# 6     7            Nanteza Dorcus   21     69   157.48                   1
# 7     8             Mbabazi Angel   19     57   167.64                   1
# 8     9            Namara Racheal   19     55   154.94                   1
# 9    10       Lwamulungi Sheillah   22     78   162.56                   1
# 10   11           Nakawuka Sandra   25     60   175.26                   1
# ...

# %%
import matplotlib.pyplot as plt

# %%
h=df["height"]

# %%
w = df["weight"]

# %%
a = df["age"]

# %%
plt.plot("h", "w", "o")

# %%
#yes people tend to gain weight
plt.xlabel("age(years)")
plt.ylabel("weight(kg)")
plt.title('Distribution of Weight')
plt.show()

# %%
from empiricaldist import Pmf

# %%
age=df['age']

# %%
pmf_age = Pmf.from_seq(age)

# %%
pmf_age.bar()
plt.xlabel('age')
plt.ylabel('Probability')
plt.title('PMF of age')
plt.show()
